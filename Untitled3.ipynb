# %%
import pandas as pd

# %%
data= pd.read_csv("C:/Users/lenovo/Desktop/Global YouTube Statistics.csv",encoding='latin-1')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info
# Out:
# <bound method DataFrame.info of      rank                    Youtuber  subscribers   video views
# 0       1                    T-Series  245000000.0  2.280000e+11  \
# 1       2              YouTube Movies  170000000.0           NaN
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes          NaN  1.640000e+11
# 4       5                   SET India  159000000.0  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿   12300000.0  9.029610e+09
# 991   992    Free Fire India Official   12300000.0  1.674410e+09
# 992   993                       Panda   12300000.0  2.214684e+09
# 993   994                 RobTopGames   12300000.0  3.741235e+08
# 994   995                Make Joke Of   12300000.0  2.129774e+09
#
#              category                       Title   uploads         Country
# 0               Music                    T-Series   20082.0           India  \
# ...

# %%
data.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank
# count  995.00000  9.940000e+02  9.870000e+02     959.000000      9.910000e+02  \
# mean   498.00000  2.284256e+07  1.112902e+10    9532.002086      5.477364e+05
# std    287.37606  1.697033e+07  1.413275e+10   34739.778094      1.355601e+06
# min      1.00000  1.230000e+07  2.634000e+03       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.344888e+09     231.500000      3.175000e+02
# 50%    498.00000  1.770000e+07  7.776706e+09     776.000000      9.120000e+02
# 75%    746.50000  2.457500e+07  1.358802e+10    2859.500000      3.556500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days
# count    879.000000         961.000000                      9.390000e+02  \
# mean     386.053470         738.748179                      1.756103e+08
# ...

# %%
data= data.drop_duplicates()
data
# Out:
#      rank                    Youtuber  subscribers   video views
# 0       1                    T-Series  245000000.0  2.280000e+11  \
# 1       2              YouTube Movies  170000000.0           NaN
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes          NaN  1.640000e+11
# 4       5                   SET India  159000000.0  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿   12300000.0  9.029610e+09
# 991   992    Free Fire India Official   12300000.0  1.674410e+09
# 992   993                       Panda   12300000.0  2.214684e+09
# 993   994                 RobTopGames   12300000.0  3.741235e+08
# 994   995                Make Joke Of   12300000.0  2.129774e+09
#
#              category                       Title   uploads         Country
# 0               Music                    T-Series   20082.0           India  \
# ...

# %%
data.isnull()
# Out:
#       rank  Youtuber  subscribers  video views  category  Title  uploads
# 0    False     False        False        False     False  False    False  \
# 1    False     False        False         True     False  False    False
# 2    False     False        False        False     False  False    False
# 3    False     False         True        False     False  False    False
# 4    False     False        False        False     False  False    False
# ..     ...       ...          ...          ...       ...    ...      ...
# 990  False     False        False        False     False  False    False
# 991  False     False        False        False     False  False    False
# 992  False     False        False        False      True  False    False
# 993  False     False        False        False     False  False    False
# 994  False     False        False        False     False  False    False
#
#      Country  Abbreviation  channel_type  ...  subscribers_for_last_30_days
# ...

# %%
data.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  1
# video views                                  8
# category                                    46
# Title                                        0
# uploads                                     36
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             4
# country_rank                               116
# channel_type_rank                           34
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                    118
# highest_monthly_earnings                    89
# lowest_yearly_earnings                      89
# highest_yearly_earnings                     79
# subscribers_for_last_30_days               338
# created_year                                 5
# ...

# %%
data.notnull()
# Out:
#      rank  Youtuber  subscribers  video views  category  Title  uploads
# 0    True      True         True         True      True   True     True  \
# 1    True      True         True        False      True   True     True
# 2    True      True         True         True      True   True     True
# 3    True      True        False         True      True   True     True
# 4    True      True         True         True      True   True     True
# ..    ...       ...          ...          ...       ...    ...      ...
# 990  True      True         True         True      True   True     True
# 991  True      True         True         True      True   True     True
# 992  True      True         True         True     False   True     True
# 993  True      True         True         True      True   True     True
# 994  True      True         True         True      True   True     True
#
#      Country  Abbreviation  channel_type  ...  subscribers_for_last_30_days
# ...

# %%
data.isnull().sum().sum()
# Out:
# 2041

# %%
data2= data.fillna(value=0)
data2
# Out:
#      rank                    Youtuber  subscribers   video views
# 0       1                    T-Series  245000000.0  2.280000e+11  \
# 1       2              YouTube Movies  170000000.0  0.000000e+00
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes          0.0  1.640000e+11
# 4       5                   SET India  159000000.0  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿   12300000.0  9.029610e+09
# 991   992    Free Fire India Official   12300000.0  1.674410e+09
# 992   993                       Panda   12300000.0  2.214684e+09
# 993   994                 RobTopGames   12300000.0  3.741235e+08
# 994   995                Make Joke Of   12300000.0  2.129774e+09
#
#              category                       Title   uploads         Country
# 0               Music                    T-Series   20082.0           India  \
# ...

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
data
# Out:
#      rank                    Youtuber  subscribers   video views
# 0       1                    T-Series  245000000.0  2.280000e+11  \
# 1       2              YouTube Movies  170000000.0           NaN
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes          NaN  1.640000e+11
# 4       5                   SET India  159000000.0  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿   12300000.0  9.029610e+09
# 991   992    Free Fire India Official   12300000.0  1.674410e+09
# 992   993                       Panda   12300000.0  2.214684e+09
# 993   994                 RobTopGames   12300000.0  3.741235e+08
# 994   995                Make Joke Of   12300000.0  2.129774e+09
#
#              category                       Title   uploads         Country
# 0               Music                    T-Series   20082.0           India  \
# ...

# %%
data2= data.fillna(value=0)
data2
# Out:
#      rank                    Youtuber  subscribers   video views
# 0       1                    T-Series  245000000.0  2.280000e+11  \
# 1       2              YouTube Movies  170000000.0  0.000000e+00
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes          0.0  1.640000e+11
# 4       5                   SET India  159000000.0  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿   12300000.0  9.029610e+09
# 991   992    Free Fire India Official   12300000.0  1.674410e+09
# 992   993                       Panda   12300000.0  2.214684e+09
# 993   994                 RobTopGames   12300000.0  3.741235e+08
# 994   995                Make Joke Of   12300000.0  2.129774e+09
#
#              category                       Title   uploads         Country
# 0               Music                    T-Series   20082.0           India  \
# ...

# %%
data3 = data.fillna(method='pad')
data3
# Out:
#      rank                    Youtuber  subscribers   video views
# 0       1                    T-Series  245000000.0  2.280000e+11  \
# 1       2              YouTube Movies  170000000.0  2.280000e+11
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes  166000000.0  1.640000e+11
# 4       5                   SET India  159000000.0  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿   12300000.0  9.029610e+09
# 991   992    Free Fire India Official   12300000.0  1.674410e+09
# 992   993                       Panda   12300000.0  2.214684e+09
# 993   994                 RobTopGames   12300000.0  3.741235e+08
# 994   995                Make Joke Of   12300000.0  2.129774e+09
#
#              category                       Title   uploads         Country
# 0               Music                    T-Series   20082.0           India  \
# ...

# %%
data4= data.fillna(method='bfill')
data4
# Out:
#      rank                    Youtuber  subscribers   video views
# 0       1                    T-Series  245000000.0  2.280000e+11  \
# 1       2              YouTube Movies  170000000.0  2.836884e+10
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes  159000000.0  1.640000e+11
# 4       5                   SET India  159000000.0  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿   12300000.0  9.029610e+09
# 991   992    Free Fire India Official   12300000.0  1.674410e+09
# 992   993                       Panda   12300000.0  2.214684e+09
# 993   994                 RobTopGames   12300000.0  3.741235e+08
# 994   995                Make Joke Of   12300000.0  2.129774e+09
#
#              category                       Title   uploads         Country
# 0               Music                    T-Series   20082.0           India  \
# ...

# %%
import numpy as np
from scipy import stats

# %%
data2.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data2.drop(["Population"], axis=1,inplace= True)
data2.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Unemployment rate',
#        'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
Q1= data2.quantile(0.25)
Q3= data2.quantile(0.75)
IQR=Q3-Q1
print(IQR)

# %%
data2= data2[~((data2<(Q1-1.5*IQR))|(data2>(Q3+1.5*IQR))).any(axis=1)]
data2
